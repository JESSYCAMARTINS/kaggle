# %% [markdown]
# <a href="https://colab.research.google.com/github/JESSYCAMARTINS/kaggle/blob/main/C%C3%B3pia_de_Ol%C3%A1%2C_este_%C3%A9_o_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df= pd.read_excel("WDW_Ride_Data_DW.xlsx")
df
# Out:
#                                          Ride_name Park_location  \
# 0                           Alien Swirling Saucers            HS
# 1                                    Astro Orbiter            MK
# 2                         Avatar Flight of Passage            AK
# 3                    Big Thunder Mountain Railroad            MK
# 4               Buzz Lightyear's Space Ranger Spin            MK
# 5                                         Dinosaur            AK
# 6                        Dumbo the Flying Elephant            MK
# 7                               Expedition Everest            AK
# 8                                Frozen Ever After            EC
# 9   Gran Fiesta Tour Starring The Three Caballeros            EC
# 10                                 Haunted Mansion            MK
# 11                              It's a Small World            MK
# 12           Journey Into Imagination with Figment            EC
# ...

# %%
df["Ride_type_thrill"] = np.where(df["Ride_type_thrill"] == "No", 0, 1)

# %%
df["Ride_type_spinning"] = np.where(df["Ride_type_spinning"] == "No", 0, 1)

# %%
df["Ride_type_slow"] = np.where(df["Ride_type_slow"] == "No", 0, 1)

# %%
df["Ride_type_small_drops"] = np.where(df["Ride_type_small_drops"] == "No", 0, 1)

# %%
df["Ride_type_dark"] = np.where(df["Ride_type_dark"] == "No", 0, 1)

# %%
df["Age_interest_teens"] = np.where(df["Age_interest_teens"] == "No", 0, 1)

# %%
df["Age_interest_adults"] = np.where(df["Age_interest_adults"] == "No", 0, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ride_name                  46 non-null     object
#  1   Park_location              46 non-null     object
#  2   Park_area                  46 non-null     object
#  3   Ride_type_all              46 non-null     object
#  4   Ride_type_thrill           46 non-null     int64
#  5   Ride_type_spinning         46 non-null     int64
#  6   Ride_type_slow             46 non-null     int64
#  7   Ride_type_small_drops      46 non-null     int64
#  8   Ride_type_big_drops        46 non-null     object
#  9   Ride_type_dark             46 non-null     int64
#  10  Ride_type_scary            46 non-null     object
#  11  Ride_type_water            46 non-null     object
#  12  Fast_pass                  46 non-null     object
# ...

# %%
df["Ride_type_big_drops"] = np.where(df["Ride_type_big_drops"] == "No", 0, 1)

# %%
df["Ride_type_scary"] = np.where(df["Ride_type_scary"] == "No", 0, 1)

# %%
df["Ride_type_water"] = np.where(df["Ride_type_water"] == "No", 0, 1)

# %%
df["Fast_pass"] = np.where(df["Fast_pass"] == "No", 0, 1)

# %%
df["Classic"] = np.where(df["Classic"] == "No", 0, 1)

# %%
df["Age_interest_all"] = np.where(df["Age_interest_all"] == "No", 0, 1)

# %%
df["Age_interest_preschoolers"] = np.where(df["Age_interest_preschoolers"] == "No", 0, 1)

# %%
df["Age_interest_kids"] = np.where(df["Age_interest_kids"] == "No", 0, 1)

# %%
df["Age_interest_teens"] = np.where(df["Age_interest_teens"] == "No", 0, 1)

# %%
df
# Out:
#                                          Ride_name Park_location  \
# 0                           Alien Swirling Saucers            HS
# 1                                    Astro Orbiter            MK
# 2                         Avatar Flight of Passage            AK
# 3                    Big Thunder Mountain Railroad            MK
# 4               Buzz Lightyear's Space Ranger Spin            MK
# 5                                         Dinosaur            AK
# 6                        Dumbo the Flying Elephant            MK
# 7                               Expedition Everest            AK
# 8                                Frozen Ever After            EC
# 9   Gran Fiesta Tour Starring The Three Caballeros            EC
# 10                                 Haunted Mansion            MK
# 11                              It's a Small World            MK
# 12           Journey Into Imagination with Figment            EC
# ...

# %%
df.dropna(subset=['TA_Stars'],inplace = True)
df
# Out:
#                                          Ride_name Park_location  \
# 1                                    Astro Orbiter            MK
# 2                         Avatar Flight of Passage            AK
# 3                    Big Thunder Mountain Railroad            MK
# 4               Buzz Lightyear's Space Ranger Spin            MK
# 5                                         Dinosaur            AK
# 6                        Dumbo the Flying Elephant            MK
# 7                               Expedition Everest            AK
# 8                                Frozen Ever After            EC
# 9   Gran Fiesta Tour Starring The Three Caballeros            EC
# 10                                 Haunted Mansion            MK
# 11                              It's a Small World            MK
# 12           Journey Into Imagination with Figment            EC
# 13                                   Jungle Cruise            MK
# ...

# %%
x=df[['Ride_type_thrill',"Ride_type_spinning",'Ride_type_slow','Ride_type_small_drops','Ride_type_big_drops','Ride_type_dark','Ride_type_water','Age_interest_kids','Age_interest_tweens','Age_interest_teens','Age_interest_adults']]
y=df[['TA_Stars']]

# %%
# !pip install TPOT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 9.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11938 sha256=6501a0f442ac4593f8e01cf4d9ab2a8ebba962241e8fc14f39b8aaf2f4210d96
#   Stored in directory: /root/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from tpot import TPOTRegressor

# %%
tpot = TPOTRegressor(generations=4, population_size=20, verbosity=2, n_jobs=-1, cv=5)

# %%
! cat 'tpot_exported_pipeline.py'
# Out:
# cat: tpot_exported_pipeline.py: No such file or directory
